# %%
import numpy as nm  
import matplotlib.pyplot as mtp  
import pandas as pd

# %% [markdown]
# ### NUMBER OF VITAL EVENTS BY SEX, REGION, PROVINCE, AND CITY/MUNICIPALITY, PHILIPPINES: JANUARY TO SEPTEMBER 2020 (Preliminary)
# ### As of 30 December 2020

# %% [markdown]
# ### RAW DATA

# %%
data= pd.read_csv('VStable.csv')  
data
# Out:
#                     REGION, PROVINCE, CITY/MUNICIPALITY  \
# 0                                           PHILIPPINES
# 1                         NATIONAL CAPITAL REGION (NCR)
# 2                                        FIRST DISTRICT
# 3                                        City of Manila
# 4                                       SECOND DISTRICT
# ...                                                 ...
# 1738  Source: Philippine Statistics Authority, Civil...
# 1739  Note: Figures are results of actual registrati...
# 1740  Civil Registration is a continuous process. He...
# 1741  * Includes babies born in the Philippines whos...
# 1742  ** Includes persons died in the Philippines wh...
#
#      Total Number of Live Births by Sex and by Usual Residence of Mother*   \
# 0                                             1,038,711
# 1                                               137,616
# 2                                                19,702
# ...

# %% [markdown]
# ### THE CODE BELOW WILL OUTPUT ONLY THE REPRESENTING REGIONS AND REMOVES INFORMATION BELOW ABOUT THE DATA SET WHICH ARE INDEX 1739 AND ABOVE

# %%
data[0:1738]
# Out:
#      REGION, PROVINCE, CITY/MUNICIPALITY  \
# 0                            PHILIPPINES
# 1          NATIONAL CAPITAL REGION (NCR)
# 2                         FIRST DISTRICT
# 3                         City of Manila
# 4                        SECOND DISTRICT
# ...                                  ...
# 1733                           Sitangkai
# 1734                         South Ubian
# 1735                            Tandubas
# 1736                      Turtle Islands
# 1737                     FOREIGN COUNTRY
#
#      Total Number of Live Births by Sex and by Usual Residence of Mother*   \
# 0                                             1,038,711
# 1                                               137,616
# 2                                                19,702
# 3                                                19,702
# 4                                                49,007
# ...                                                 ...
# ...

# %% [markdown]
# ### THE CODE BELOW WILL OUTPUT VITAL EVENTS SPECIFIC TO THE VISAYAN REGION

# %% [markdown]
# ### IT WILL ALSO REMOVE ROW THAT HAD DATA COMBINED OR COMPOSITE SUCH AS THE REGION NAMES AND PHILIPPINES ALONG WITH THE CITIES EXCEPT FOR CITIES THAT DOES NOT HAVE MUNICIPALITIES

# %%
visayas_region= data[822:1249].drop(data.index[[822,823,843,862,880,886,930,964,965,1014,1065,1091,1101,
                                                1102,1111,1135,1178,1203,1230]])
visayas_region
# Out:
#      REGION, PROVINCE, CITY/MUNICIPALITY  \
# 824                              Altavas
# 825                               Balete
# 826                                Banga
# 827                                Batan
# 828                             Buruanga
# ...                                  ...
# 1244                         San Ricardo
# 1245                              Silago
# 1246                               Sogod
# 1247                         Tomas Oppus
# 1248                    CITY OF TACLOBAN
#
#      Total Number of Live Births by Sex and by Usual Residence of Mother*   \
# 824                                                 214
# 825                                                 314
# 826                                                 411
# 827                                                 243
# 828                                                 133
# ...                                                 ...
# ...
